# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_parquet("../data/sample_data_v2.parquet")
data.head()
# Out:
#                                       Message-ID  \
# 0  <22993823.1075858194210.JavaMail.evans@thyme>
# 1   <4916122.1075858194380.JavaMail.evans@thyme>
# 2  <19881626.1075858194498.JavaMail.evans@thyme>
# 3  <14261412.1075858194401.JavaMail.evans@thyme>
# 4  <10797875.1075858194232.JavaMail.evans@thyme>
#
#                               Date                           From  \
# 0  Wed, 13 Dec 2000 06:34:00 -0800     public.relations@enron.com
# 1  Sun, 10 Dec 2000 15:32:00 -0800                  ksu93@aol.com
# 2  Fri, 08 Dec 2000 07:51:00 -0800        rhonda.denton@enron.com
# 3  Sun, 10 Dec 2000 03:35:00 -0800                  ksu93@aol.com
# 4  Tue, 12 Dec 2000 22:01:00 -0800  enron.announcements@enron.com
#
#                                                   To  \
# 0                              all.houston@enron.com
# 1  mbower@bellatlantic.net, m_besch@yahoo.com, mi...
# 2  tim.belden@enron.com, dana.davis@enron.com, ge...
# ...

# %%
data.isnull().sum()
# Out:
# Message-ID                       0
# Date                             0
# From                             0
# To                               0
# Subject                          1
# Cc                               3
# Mime-Version                     3
# Content-Type                     3
# Content-Transfer-Encoding        3
# Bcc                              3
# X-From                           3
# X-To                             3
# X-cc                             3
# X-bcc                            3
# X-Folder                      4549
# X-Origin                     98948
# X-FileName                   99306
# body                             0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132464 entries, 0 to 132463
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Message-ID                 132464 non-null  object
#  1   Date                       132464 non-null  object
#  2   From                       132464 non-null  object
#  3   To                         132464 non-null  object
#  4   Subject                    132463 non-null  object
#  5   Cc                         132461 non-null  object
#  6   Mime-Version               132461 non-null  object
#  7   Content-Type               132461 non-null  object
#  8   Content-Transfer-Encoding  132461 non-null  object
#  9   Bcc                        132461 non-null  object
#  10  X-From                     132461 non-null  object
#  11  X-To                       132461 non-null  object
#  12  X-cc                       132461 non-null  object
# ...

# %%
data.describe()
# Out:
#                                            Message-ID  \
# count                                          132464
# unique                                         132464
# top     <22993823.1075858194210.JavaMail.evans@thyme>
# freq                                                1
#
#                                    Date                     From  \
# count                            132464                   132464
# unique                            66811                     6741
# top     Mon, 31 Dec 1979 16:00:00 -0800  jeff.dasovich@enron.com
# freq                                 99                     9438
#
#                              To Subject      Cc  \
# count                    132464  132463  132461
# unique                    22795   47593    9813
# top     jeff.dasovich@enron.com     1.0     1.0
# freq                       3953    4546   94757
#
#                           Mime-Version Content-Type Content-Transfer-Encoding  \
# ...

# %%
data.drop_duplicates()
# Out:
#                                            Message-ID  \
# 0       <22993823.1075858194210.JavaMail.evans@thyme>
# 1        <4916122.1075858194380.JavaMail.evans@thyme>
# 2       <19881626.1075858194498.JavaMail.evans@thyme>
# 3       <14261412.1075858194401.JavaMail.evans@thyme>
# 4       <10797875.1075858194232.JavaMail.evans@thyme>
# ...                                               ...
# 132459   <8671361.1075842232801.JavaMail.evans@thyme>
# 132460   <9393980.1075842236755.JavaMail.evans@thyme>
# 132461   <6240409.1075842219838.JavaMail.evans@thyme>
# 132462  <25418907.1075842226491.JavaMail.evans@thyme>
# 132463  <16796044.1075842247794.JavaMail.evans@thyme>
#
#                                    Date                           From  \
# 0       Wed, 13 Dec 2000 06:34:00 -0800     public.relations@enron.com
# 1       Sun, 10 Dec 2000 15:32:00 -0800                  ksu93@aol.com
# 2       Fri, 08 Dec 2000 07:51:00 -0800        rhonda.denton@enron.com
# ...

# %%
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
from spacy.lang.en import English
from wordcloud import WordCloud

# %%
plt.figure(figsize = (16,14))
wc = WordCloud(min_font_size = 3,  max_words = 3000 , width = 1600 , height = 800 , stopwords = STOP_WORDS).generate(str(" ".join(data['body'])))
plt.imshow(wc, interpolation = 'bilinear')

# %%
data['Date'] = pd.to_datetime(data['Date'])

# %%
data['To'].value_counts().head(10)
# Out:
# jeff.dasovich@enron.com     3953
# pete.davis@enron.com        2776
# daren.farmer@enron.com      2064
# chris.germany@enron.com     1398
# jdasovic@enron.com          1053
# john.griffith@enron.com      957
# rod.hayslett@enron.com       846
# dan.hyvl@enron.com           825
# portland.shift@enron.com     732
# mark.guzman@enron.com        682
# Name: To, dtype: int64

# %%
data['From'].value_counts().head(10)
# Out:
# jeff.dasovich@enron.com          9438
# chris.germany@enron.com          8689
# drew.fossum@enron.com            3627
# darron.giron@enron.com           2939
# david.delainey@enron.com         2937
# daren.farmer@enron.com           2812
# pete.davis@enron.com             2777
# enron.announcements@enron.com    2177
# mark.haedicke@enron.com          1847
# chris.dorland@enron.com          1826
# Name: From, dtype: int64

# %%
data['Date'].max(), data['Date'].min()
